# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\code\pyton\Advanced Python\Advanced_python\mobile")

# %%
df.head()
# Out:
#                       model      price  spec scroe  \
# 0            OnePlus Nord 6    ₹38,999          81
# 1  Samsung Galaxy S25 Ultra  ₹1,10,000          89
# 2               Vivo T5 Pro    ₹29,999          72
# 3     Samsung Galaxy S25 FE    ₹50,743          77
# 4               Vivo T5x 5G    ₹18,999          66
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 2            Snapdragon 7s Gen4, Octa Core Processor
# 3          Exynos 2400, Deca Core, 3.2 GHz Processor
# 4  Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model       1020 non-null   str
#  1   price       1020 non-null   str
#  2   spec scroe  1020 non-null   int64
#  3   sim         1020 non-null   str
#  4   processor   1020 non-null   str
#  5   ram         1020 non-null   str
#  6   battery     1020 non-null   str
#  7   display     1020 non-null   str
#  8   camera      1019 non-null   str
#  9   os          994 non-null    str
# dtypes: int64(1), str(9)
# memory usage: 79.8 KB

# %%
df.describe()
# Out:
#         spec scroe
# count  1020.000000
# mean     65.885294
# std      14.058394
# min       6.000000
# 25%      57.000000
# 50%      66.000000
# 75%      75.250000
# max      98.000000

# %% [markdown]
# quality issue-
#
# 1.model-consistancy
#
# 2.price-validity
#
# 3.completness

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#                       model      price  spec scroe  \
# 0            OnePlus Nord 6    ₹38,999          81
# 1  Samsung Galaxy S25 Ultra  ₹1,10,000          89
# 2               Vivo T5 Pro    ₹29,999          72
# 3     Samsung Galaxy S25 FE    ₹50,743          77
# 4               Vivo T5x 5G    ₹18,999          66
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 2            Snapdragon 7s Gen4, Octa Core Processor
# 3          Exynos 2400, Deca Core, 3.2 GHz Processor
# 4  Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...
#
# ...

# %%
df1['price']=df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
df1.head()
# Out:
#                       model   price  spec scroe  \
# 0            OnePlus Nord 6   38999          81
# 1  Samsung Galaxy S25 Ultra  110000          89
# 2               Vivo T5 Pro   29999          72
# 3     Samsung Galaxy S25 FE   50743          77
# 4               Vivo T5x 5G   18999          66
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 2            Snapdragon 7s Gen4, Octa Core Processor
# 3          Exynos 2400, Deca Core, 3.2 GHz Processor
# 4  Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model       1020 non-null   str
#  1   price       1020 non-null   int64
#  2   spec scroe  1020 non-null   int64
#  3   sim         1020 non-null   str
#  4   processor   1020 non-null   str
#  5   ram         1020 non-null   str
#  6   battery     1020 non-null   str
#  7   display     1020 non-null   str
#  8   camera      1019 non-null   str
#  9   os          994 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 79.8 KB

# %%
len(df1[df1['price']<=4000])
# Out:
# 15

# %%
df1=df1[df1['price']>=4000]

# %%
df1
# Out:
#                                 model   price  spec scroe  \
# 0                      OnePlus Nord 6   38999          81
# 1            Samsung Galaxy S25 Ultra  110000          89
# 2                         Vivo T5 Pro   29999          72
# 3               Samsung Galaxy S25 FE   50743          77
# 4                         Vivo T5x 5G   18999          66
# ...                               ...     ...         ...
# 1015  Realme C85 5G (6GB RAM + 128GB)   17999          55
# 1016                        Vivo X500   57990          83
# 1017   Vivo Y19s 5G (4GB RAM + 128GB)   13499          50
# 1018                  Oukitel WP60 5G   24699          64
# 1019                         Vivo S50   39990          76
#
#                                                     sim  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1005 entries, 0 to 1019
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model       1005 non-null   str
#  1   price       1005 non-null   int64
#  2   spec scroe  1005 non-null   int64
#  3   sim         1005 non-null   str
#  4   processor   1005 non-null   str
#  5   ram         1005 non-null   str
#  6   battery     1005 non-null   str
#  7   display     1005 non-null   str
#  8   camera      1005 non-null   str
#  9   os          989 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 86.4 KB

# %%
df1[df1['os'].isnull()]
# Out:
#                                          model   price  spec scroe  \
# 185                               Oppo Find N6  129990          97
# 215                     Motorola Razr 60 Ultra   79999          98
# 405                            Nokia 2780 Flip    4990          25
# 568                              Ai+ Nova Flip   39999          76
# 587                         Huawei Mate 80 Pro   75990          81
# 591  Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   38350          72
# 597                                HMD Terra M    8999          28
# 599                         Motorola Razr Fold  139999          88
# 767                              Xiaomi 17 Pro   82990          92
# 816                            Nokia 2660 Flip    4649          15
# 895                          Nokia 2720 V Flip    6199          22
# 911                        Lava Blaze Duo 3 5G   17999          59
# 932                           Motorola Razr 70   59990          83
# ...

# %%
df1[df1['model'].str.contains('Apple', na=False, case=False)]
# Out:
#                                 model   price  spec scroe  \
# 22                    Apple iPhone 17   82900          76
# 57                    Apple iPhone 16   69900          70
# 78            Apple iPhone 17 Pro Max  149900          81
# 90                    Apple iPhone 15   59900          64
# 111              Apple iPhone 15 Plus   59994          66
# 137               Apple iPhone 16 Pro  103990          75
# 174               Apple iPhone 17 Pro  134900          74
# 181                   Apple iPhone 13   45690          55
# 198           Apple iPhone 18 Pro Max  179900          77
# 257                  Apple iPhone 17e   64900          63
# 271               Apple iPhone 18 Pro  139900          72
# 274                 Apple iPhone Fold  199990          80
# 301                  Apple iPhone Air   94990          64
# 306           Apple iPhone 16 Pro Max  127490          80
# 337              Apple iPhone 16 Plus   79900          70
# ...

# %%
df1.drop([453,271],inplace=True)

# %%
df1[df1['model'].str.contains('Apple', na=False, case=False)]
# Out:
#                                 model   price  spec scroe  \
# 22                    Apple iPhone 17   82900          76
# 57                    Apple iPhone 16   69900          70
# 78            Apple iPhone 17 Pro Max  149900          81
# 90                    Apple iPhone 15   59900          64
# 111              Apple iPhone 15 Plus   59994          66
# 137               Apple iPhone 16 Pro  103990          75
# 174               Apple iPhone 17 Pro  134900          74
# 181                   Apple iPhone 13   45690          55
# 198           Apple iPhone 18 Pro Max  179900          77
# 257                  Apple iPhone 17e   64900          63
# 274                 Apple iPhone Fold  199990          80
# 301                  Apple iPhone Air   94990          64
# 306           Apple iPhone 16 Pro Max  127490          80
# 337              Apple iPhone 16 Plus   79900          70
# 358                   Apple iPhone 14   52190          58
# ...

# %%
df1.drop([274],inplace=True)

# %%
df1.drop([597],inplace=True)

# %%
df1[df1['model']=='Oppo Find N6']
# Out:
#             model   price  spec scroe  \
# 185  Oppo Find N6  129990          97
#
#                                                    sim  \
# 185  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                              processor  \
# 185  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#                            ram                                  battery  \
# 185  12 GB RAM, 256 GB inbuilt  6000 mAh Battery with 80W Fast Charging
#
#                                                display  \
# 185  8.12 inches, 2248 x 2480 px, 120 Hz Display wi...
#
#                              camera   os
# 185  Foldable Display, Dual Display  NaN

# %%
df1.loc[185, 'camera'] = "200 MP + 50 MP + 50 MP Triple Rear & 20 MP + 20 MP Dual Front Camera"

# %%
df1.loc[215, 'camera'] = "50 MP + 50 MP Dual Rear & 50 MP Front Camera"

# %%
df1.loc[591, 'camera'] = "12 MP + 12 MP Dual Rear & 10 MP Front Camera"

# %%
df1.loc[767, 'camera'] = "50 MP + 50 MP + 50 MP Triple Rear & 50 MP Front Camera"

# %%
df1.loc[767, 'os'] = "Android v16"

# %%
df1.drop([405,816,895,],inplace=True)

# %%
df1.loc[911, 'camera'] = "50 MP Dual Rear & 8 MP Front Camera"

# %%
df1.loc[932, 'camera'] = "50 MP + 50 MP Dual Rear & 32 MP Front Camera"

# %%
df1.loc[988, 'camera'] = "50 MP + 8 MP + 8 MP Triple Rear & 16 MP Front Camera"

# %%
df1[df1['os'].isnull()]
# Out:
#                                          model   price  spec scroe  \
# 185                               Oppo Find N6  129990          97
# 215                     Motorola Razr 60 Ultra   79999          98
# 568                              Ai+ Nova Flip   39999          76
# 587                         Huawei Mate 80 Pro   75990          81
# 591  Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   38350          72
# 599                         Motorola Razr Fold  139999          88
# 911                        Lava Blaze Duo 3 5G   17999          59
# 932                           Motorola Razr 70   59990          83
# 953                        Motorola Razr 60 5G   49999          81
# 962                 Samsung Galaxy Z Flip 7 5G   95999          88
# 988                             Lava Agni 3 5G   20999          67
#
#                                                    sim  \
# 185  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...

# %%
index=[185,215,405,568,591,599,767,816,895,911,932,953,962,988]

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 998 entries, 0 to 1019
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model       998 non-null    str
#  1   price       998 non-null    int64
#  2   spec scroe  998 non-null    int64
#  3   sim         998 non-null    str
#  4   processor   998 non-null    str
#  5   ram         998 non-null    str
#  6   battery     998 non-null    str
#  7   display     998 non-null    str
#  8   camera      998 non-null    str
#  9   os          987 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 118.1 KB

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                74
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera               40
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera               38
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera               34
# 50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front Camera     34
#                                                           ..
# 48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera      1
# 64 MP Quad Rear & 16 MP Front Camera                       1
# iOS v14.0                                                  1
# 48 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera      1
# 50 MP + 48 MP + 10 MP Triple Rear & 12 MP Front Camera     1
# Name: count, Length: 209, dtype: int64

# %%
df1['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 25W Fast Charging                45
# 5000 mAh Battery with 45W Fast Charging                39
# 7000 mAh Battery with 80W Fast Charging                37
# 5000 mAh Battery with 18W Fast Charging                31
# 5000 mAh Battery with 33W Fast Charging                30
#                                                        ..
# 4500 mAh Battery with 80W Fast Charging                 1
# 6.7 inches, 1284 x 2778 px Display with Large Notch     1
# 4000 mAh Battery with 27W Fast Charging                 1
# 8000 mAh Battery with 800W Fast Charging                1
# 10000 mAh Battery with 33W Fast Charging                1
# Name: count, Length: 254, dtype: int64

# %%
df1[df1['battery']=='6.7 inches, 1284 x 2778 px Display with Large Notch']
# Out:
#                         model   price  spec scroe  \
# 1004  Apple iPhone 12 Pro Max  119900          61
#
#                                           sim  \
# 1004  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                      processor                       ram  \
# 1004  Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                                 battery  \
# 1004  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                 display     camera         os
# 1004  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...  iOS v14.0  iOS v14.0

# %%
df1.loc[1004, 'camera'] = "12 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera"

# %%
df1.loc[1004, 'battery'] = "3687 mAh"

# %%
df1['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 25W Fast Charging     45
# 5000 mAh Battery with 45W Fast Charging     39
# 7000 mAh Battery with 80W Fast Charging     37
# 5000 mAh Battery with 18W Fast Charging     31
# 5000 mAh Battery with 33W Fast Charging     30
#                                             ..
# 4500 mAh Battery with 80W Fast Charging      1
# 3687 mAh                                     1
# 4000 mAh Battery with 27W Fast Charging      1
# 8000 mAh Battery with 800W Fast Charging     1
# 10000 mAh Battery with 33W Fast Charging     1
# Name: count, Length: 254, dtype: int64

# %%
df1['processor'].value_counts()
# Out:
# processor
# Dimensity 6300, Octa Core, 2.4 GHz Processor              120
# Octa Core Processor                                        52
# Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz Processor     26
# Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor            24
# Dimensity 7400, Octa Core, 2.6 GHz Processor               24
#                                                          ...
# Exynos 2100, Octa Core, 2.9 GHz Processor                   1
# Helio  G95, Octa Core, 2.05 GHz Processor                   1
# Bionic A14, Hexa Core, 3.1 GHz Processor                    1
# Snapdragon  855, Octa Core, 2.8 GHz Processor               1
# Exynos, Deca Core Processor                                 1
# Name: count, Length: 225, dtype: int64

# %%
df1['display'].value_counts()
# Out:
# display
# 6.77 inches, 1080 x 2392 px, 120 Hz Display with Punch Hole    50
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    46
# 6.67 inches, 720 x 1604 px, 120 Hz Display with Punch Hole     22
# 6.75 inches, 720 x 1570 px, 120 Hz Display with Punch Hole     20
# 6.7 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole     19
#                                                                ..
# 6.74 inches, 720 x 1600 px Display                              1
# 6.9 inches, 1272 x 2772 px, 120 Hz Display with Punch Hole      1
# 7.69 inches, 1320 x 2120 px Display with Punch Hole             1
# 6.67 inches, 1216 x 2640 px, 120 Hz Display with Punch Hole     1
# 7.2 inches, 720 x 1560 px, 120 Hz Display with Punch Hole       1
# Name: count, Length: 292, dtype: int64

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt                   219
# 8 GB RAM, 256 GB inbuilt                   213
# 12 GB RAM, 256 GB inbuilt                  191
# 6 GB RAM, 128 GB inbuilt                   125
# 4 GB RAM, 128 GB inbuilt                    71
# 4 GB RAM, 64 GB inbuilt                     55
# 12 GB RAM, 512 GB inbuilt                   44
# 16 GB RAM, 512 GB inbuilt                   37
# 16 GB RAM, 256 GB inbuilt                   11
# 3 GB RAM, 64 GB inbuilt                      5
# 12 GB RAM, 128 GB inbuilt                    4
# 6 GB RAM, 256 GB inbuilt                     4
# 8 GB RAM, 512 GB inbuilt                     3
# 16 GB RAM, 1 TB inbuilt                      2
# 2 GB RAM, 64 GB inbuilt                      2
# 256 GB inbuilt                               2
# 12 GB RAM, 1 TB inbuilt                      2
# 128 GB inbuilt                               1
# 12 GB RAM, 2 TB inbuilt                      1
# 24 GB RAM, 1 TB inbuilt                      1
# ...

# %%
df1[df1['ram']=='5100 mAh Battery with 18W Fast Charging']
# Out:
#          model  price  spec scroe                             sim  \
# 776  Vivo Y04s   7999          39  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                    processor                                      ram  \
# 776  4 GB RAM, 64 GB inbuilt  5100 mAh Battery with 18W Fast Charging
#
#                                                battery  \
# 776  6.67 inches, 720 x 1600 px, 90 Hz Display with...
#
#                                         display  \
# 776  13 MP + 2 MP Dual Rear & 5 MP Front Camera
#
#                                camera           os
# 776  Memory Card Supported, upto 1 TB  Android v15

# %%
df1.drop([776],inplace=True)

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt      219
# 8 GB RAM, 256 GB inbuilt      213
# 12 GB RAM, 256 GB inbuilt     191
# 6 GB RAM, 128 GB inbuilt      125
# 4 GB RAM, 128 GB inbuilt       71
# 4 GB RAM, 64 GB inbuilt        55
# 12 GB RAM, 512 GB inbuilt      44
# 16 GB RAM, 512 GB inbuilt      37
# 16 GB RAM, 256 GB inbuilt      11
# 3 GB RAM, 64 GB inbuilt         5
# 12 GB RAM, 128 GB inbuilt       4
# 6 GB RAM, 256 GB inbuilt        4
# 8 GB RAM, 512 GB inbuilt        3
# 16 GB RAM, 1 TB inbuilt         2
# 2 GB RAM, 64 GB inbuilt         2
# 256 GB inbuilt                  2
# 12 GB RAM, 1 TB inbuilt         2
# 128 GB inbuilt                  1
# 12 GB RAM, 2 TB inbuilt         1
# 24 GB RAM, 1 TB inbuilt         1
# 256 GB RAM, 128 GB inbuilt      1
# 20 GB RAM, 512 GB inbuilt       1
# 8 GB RAM, 1 TB inbuilt          1
# 6 GB RAM, 64 GB inbuilt         1
# Name: count, dtype: int64

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           238
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster          200
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      169
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster               141
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                 66
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster     54
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                                31
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                      24
# Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC                              11
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    11
# Dual Sim, 3G, 4G, Wi-Fi                                       10
# Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC, IR Blaster                   8
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           7
# Dual Sim, 3G, 4G, 5G, Wi-Fi                                    6
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model       997 non-null    str
#  1   price       997 non-null    int64
#  2   spec scroe  997 non-null    int64
#  3   sim         997 non-null    str
#  4   processor   997 non-null    str
#  5   ram         997 non-null    str
#  6   battery     997 non-null    str
#  7   display     997 non-null    str
#  8   camera      997 non-null    str
#  9   os          986 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 85.7 KB

# %%
df1.head()
# Out:
#                       model   price  spec scroe  \
# 0            OnePlus Nord 6   38999          81
# 1  Samsung Galaxy S25 Ultra  110000          89
# 2               Vivo T5 Pro   29999          72
# 3     Samsung Galaxy S25 FE   50743          77
# 4               Vivo T5x 5G   18999          66
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 2            Snapdragon 7s Gen4, Octa Core Processor
# 3          Exynos 2400, Deca Core, 3.2 GHz Processor
# 4  Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...
#
# ...

# %%
brand_name=df1['model'].str.split(' ').str.get(0)

# %%
df1.insert(0,'brand_name',brand_name)

# %%
df1['brand_name']=df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 2            Snapdragon 7s Gen4, Octa Core Processor
# 3          Exynos 2400, Deca Core, 3.2 GHz Processor
# ...

# %%
has_5g=df1['sim'].str.contains('5G')
has_nfc=df1['sim'].str.contains('NFC')
has_ir=df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(5,'has_5G',has_5g)

# %%
df1.insert(6,'has_NFC',has_nfc)
df1.insert(7,'has_IR',has_ir)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# ...

# %%
processor_name=df1['processor'].str.split(',').str.get(0)

# %%
num_core=df1['processor'].str.split(',').str.get(1)

# %%
processor_speed=df1['processor'].str.split(',').str.get(2)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# ...

# %%
# ১. ভুল বানান এবং সাব-ব্র্যান্ডগুলোকে মেইন ব্র্যান্ডে ম্যাপিং করা
processor_map = {
    'mediatek': 'mediatek', 'helio': 'mediatek', 'dimensit': 'mediatek',
    'bionic': 'apple', 'a13': 'apple',
    'tensor': 'google',
    'tiger': 'unisoc',
    'a20': 'samsung' # (A20 সাধারণত Samsung এর চিপসেট)
}

# ম্যাপিং অ্যাপ্লাই করা
df1['processor_brand'] = df1['processor_brand'].replace(processor_map)

# %%
df1.insert(9,'processor_name',processor_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25956\3988945097.py in ?()
# ----> 1 df1.insert(9,'processor_name',processor_name)
#
# d:\code\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5617                 "'self.flags.allows_duplicate_labels' is False."
#    5618             )
#    5619         if not allow_duplicates and column in self.columns:
#    5620             # Should this be a different kind of error??
# -> 5621             raise ValueError(f"cannot insert {column}, already exists")
#    5622         if not is_integer(loc):
#    5623             raise TypeError("loc must be int")
#    5624         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert processor_name, already exists

# %%
df1.insert(10,'num_core',num_core)

# %%
df1.insert(11,'processor_speed',processor_speed)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# ...

# %%
processor_brand=df1['processor_name'].str.split(' ').str.get(0)

# %%
df1.insert(9,'processor_brand',processor_brand)

# %%
df1['processor_brand']=df1['processor_brand'].str.lower()

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  \
# ...

# %%
df1['num_core'].value_counts()
# Out:
# num_core
# Octa Core              827
# Octa Core Processor     64
# Hexa Core               17
# Hexa Core Processor     13
# Deca Core               12
# Deca Core Processor      2
# Nine-Cores               2
# Nine Core                1
# Single Core              1
# 1.6 GHz Processor        1
# Nine Cores               1
# Name: count, dtype: int64

# %%
df1[df1['num_core']== ' 1.6 GHz Processor']
# Out:
#     brand_name                model  price  spec scroe  \
# 541    infinix  Infinix Smart 10 HD   4999          41
#
#                                             sim  has_5G  has_NFC  has_IR  \
# 541  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster   False    False    True
#
#                         processor processor_brand processor_name  \
# 541  Octa Core, 1.6 GHz Processor            octa      Octa Core
#
#                num_core processor_speed                      ram  \
# 541   1.6 GHz Processor             NaN  2 GB RAM, 64 GB inbuilt
#
#                                      battery  \
# 541  5000 mAh Battery with 10W Fast Charging
#
#                                                display  \
# 541  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
#
#                              camera           os
# 541  13 MP Rear & 8 MP Front Camera  Android v14

# %%
# ৫৪১ নম্বর ইনডেক্সের জন্য ডাটা ঠিক করা
df1.loc[541, 'num_core'] = 'Octa Core'
df1.loc[541, 'processor_brand'] = np.nan
df1.loc[541, 'processor_name'] = '12nm'
df1.loc[541, 'processor_speed'] = '1.6 GHz Processor'

# চেক করে দেখার জন্য
df1.loc[[541]]
# Out:
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File d:\code\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1115, in Block.setitem(self, indexer, value)
#    1114 try:
# -> 1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
#
# File d:\code\.venv\Lib\site-packages\pandas\core\dtypes\cast.py:1792, in np_can_hold_element(dtype, element)
#    1790         return element
# -> 1792     raise LossySetitemError
#    1794 if dtype.kind == "c":
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[235], line 5
#       3 df1.loc[541, 'processor_brand'] = np.nan
#       4 df1.loc[541, 'processor_name'] = '12nm'
# ...

# %%
df1['num_core'].value_counts()
# Out:
# num_core
#  Octa Core              827
#  Octa Core Processor     64
#  Hexa Core               17
#  Hexa Core Processor     13
#  Deca Core               12
#  Deca Core Processor      2
#  Nine-Cores               2
#  Nine Core                1
#  Single Core              1
# Octa Core                 1
#  Nine Cores               1
# Name: count, dtype: int64

# %%
df1['num_core']=df1['num_core'].str.strip()

# %%
# ডিকশনারি তৈরি
core_map = {
    'Octa Core Processor': 'Octa Core',
    'Hexa Core Processor': 'Hexa Core',
    'Deca Core Processor': 'Deca Core',
    'Nine-Cores': 'Nine Core'
}

# একবারে সব পরিবর্তন এবং স্পেস ক্লিন করা
df1['num_core'] = df1['num_core'].replace(core_map, regex=True).str.strip()

# %%
df1['num_core'].value_counts()
# Out:
# num_core
# Octa Core      892
# Hexa Core       30
# Deca Core       14
# Nine Core        3
# Single Core      1
# Nine Cores       1
# Name: count, dtype: int64

# %%
# ১. স্প্লিট করে প্রথম অংশটি (সংখ্যা) নেওয়া
df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0)

# %%
df1['processor_speed']
# Out:
# 0        3.2
# 1       4.47
# 2        NaN
# 3        3.2
# 4        2.6
#         ...
# 1015     2.4
# 1016     NaN
# 1017     2.4
# 1018     2.5
# 1019       3
# Name: processor_speed, Length: 997, dtype: object

# %%
df1['processor_speed']=df1['processor_speed'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand_name       997 non-null    object
#  1   model            997 non-null    str
#  2   price            997 non-null    int64
#  3   spec scroe       997 non-null    int64
#  4   sim              997 non-null    str
#  5   has_5G           997 non-null    bool
#  6   has_NFC          997 non-null    bool
#  7   has_IR           997 non-null    bool
#  8   processor        997 non-null    str
#  9   processor_brand  996 non-null    object
#  10  processor_name   997 non-null    object
#  11  num_core         941 non-null    object
#  12  processor_speed  862 non-null    float64
#  13  ram              997 non-null    str
#  14  battery          997 non-null    str
#  15  display          997 non-null    str
#  16  camera           997 non-null    str
# ...

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  \
# ...

# %%
rom=df1['ram'].str.strip().str.split(',').str.get(1)

# %%
df1['ram']=df1['ram'].str.strip().str.split(',').str.get(0)

# %%
df1['ram']
# Out:
# 0        8 GB RAM
# 1       12 GB RAM
# 2        8 GB RAM
# 3        8 GB RAM
# 4        6 GB RAM
#           ...
# 1015     6 GB RAM
# 1016    12 GB RAM
# 1017     4 GB RAM
# 1018     8 GB RAM
# 1019    12 GB RAM
# Name: ram, Length: 997, dtype: object

# %%
df1.insert(14,'memoey',rom)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  \
# ...

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM          436
# 12 GB RAM         242
# 6 GB RAM          130
# 4 GB RAM          126
# 16 GB RAM          50
# 3 GB RAM            5
# 2 GB RAM            2
# 256 GB inbuilt      2
# 128 GB inbuilt      1
# 24 GB RAM           1
# 256 GB RAM          1
# 20 GB RAM           1
# Name: count, dtype: int64

# %%
df1['ram']=df1['ram'].str.strip().str.split(' ').str.get(0).astype(float)

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8.0      436
# 12.0     242
# 6.0      130
# 4.0      126
# 16.0      50
# 3.0        5
# 256.0      3
# 2.0        2
# 128.0      1
# 24.0       1
# 20.0       1
# Name: count, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand_name       997 non-null    object
#  1   model            997 non-null    str
#  2   price            997 non-null    int64
#  3   spec scroe       997 non-null    int64
#  4   sim              997 non-null    str
#  5   has_5G           997 non-null    bool
#  6   has_NFC          997 non-null    bool
#  7   has_IR           997 non-null    bool
#  8   processor        997 non-null    str
#  9   processor_brand  996 non-null    object
#  10  processor_name   997 non-null    object
#  11  num_core         941 non-null    object
#  12  processor_speed  862 non-null    float64
#  13  ram              997 non-null    float64
#  14  memoey           994 non-null    object
#  15  battery          997 non-null    str
#  16  display          997 non-null    str
# ...

# %%
df1.loc[337, 'ram'] = 8

# %%
df1.drop(columns=['memory'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 df1.drop(columns=['memory'], inplace=True)
#
# File d:\code\.venv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# ...

# %%
df1.loc[337, 'memoey'] = '128 GB inbuilt'

# %%
df1.loc[[790]]
# Out:
#     brand_name                         model  price  spec scroe  \
# 790      apple  Apple iPhone 16 Plus (256GB)  89900          70
#
#                                          sim  has_5G  has_NFC  has_IR  \
# 790  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True   False
#
#                                      processor processor_brand processor_name  \
# 790  Bionic A18, Hexa Core, 4.04 GHz Processor          bionic     Bionic A18
#
#       num_core  processor_speed    ram memoey  \
# 790  Hexa Core             4.04  256.0    NaN
#
#                                  battery  \
# 790  4674 mAh Battery with Fast Charging
#
#                                                display  \
# 790  6.7 inches, 1290 x 2796 px Display with Dynami...
#
#                                            camera       os
# 790  48 MP + 12 MP Dual Rear & 12 MP Front Camera  iOS v18

# %%
df1.loc[599, 'ram'] = 12
df1.loc[599, 'memoey'] = '256 GB inbuilt'

# %%
df1.loc[640, 'ram'] = 8

# %%
df1.loc[790, 'ram'] = 8
df1.loc[790, 'memoey'] = '256 GB inbuilt'

# %%
df1[df1['ram']>16]
# Out:
#     brand_name                       model   price  spec scroe  \
# 550    oneplus  OnePlus 13 (24GB RAM+ 1TB)   80999          90
# 708     huawei  Huawei Mate 80 RS Ultimate  159990          80
#
#                                                    sim  has_5G  has_NFC  \
# 550  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
# 708       Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC, IR Blaster    True     True
#
#      has_IR                                          processor  \
# 550    True  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 708    True                                         Kirin 9030
#
#     processor_brand      processor_name   num_core  processor_speed   ram  \
# 550      snapdragon  Snapdragon 8 Elite  Octa Core             4.32  24.0
# 708           kirin          Kirin 9030        NaN              NaN  20.0
#
#               memoey                                   battery  \
# 550     1 TB inbuilt  6000 mAh Battery with 100W Fast Charging
# ...

# %%
df1['memoey'].value_counts()
# Out:
# memoey
#  128 GB inbuilt    420
#  256 GB inbuilt    419
#  512 GB inbuilt     85
#  64 GB inbuilt      63
#  1 TB inbuilt        6
# 256 GB inbuilt       2
# 128 GB inbuilt       1
#  2 TB inbuilt        1
# Name: count, dtype: int64

# %%
battery_capasity=df1['battery'].str.strip().str.split('with').str.get(0)
fast_charging=df1['battery'].str.strip().str.split('with').str.get(1)

# %%
df1.insert(16,'battery_capasity',battery_capasity)

# %%
df1.insert(17,'fast_charging',fast_charging)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  ...  \
# ...

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
# 45W Fast Charging       157
# 80W Fast Charging       146
# 100W Fast Charging       92
# 25W Fast Charging        86
# 90W Fast Charging        82
# 33W Fast Charging        63
# 15W Fast Charging        53
# 18W Fast Charging        47
# Fast Charging            46
# 44W Fast Charging        42
# 120W Fast Charging       37
# 68W Fast Charging        19
# 30W Fast Charging        17
# 60W Fast Charging        16
# 10W Fast Charging        15
# 67W Fast Charging        13
# 50W Fast Charging        11
# 65W Fast Charging        10
# 66W Fast Charging         9
# 35W Fast Charging         4
# 20W Fast Charging         3
# 27W Fast Charging         3
# 150W Fast Charging        2
# 125W Fast Charging        2
# 70W Fast Charging         2
# 444W Fast Charging        1
# 23W Fast Charging         1
# 48W Fast Charging         1
# 55W Fast Charging         1
# 40W Fast Charging         1
# 85W Fast Charging         1
# 11200W Fast Charging      1
# ...

# %%
df1.rename(columns={'memoey': 'memory', 'battery_capasity': 'battery_capacity'}, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand_name        997 non-null    object
#  1   model             997 non-null    str
#  2   price             997 non-null    int64
#  3   spec scroe        997 non-null    int64
#  4   sim               997 non-null    str
#  5   has_5G            997 non-null    bool
#  6   has_NFC           997 non-null    bool
#  7   has_IR            997 non-null    bool
#  8   processor         997 non-null    str
#  9   processor_brand   996 non-null    object
#  10  processor_name    997 non-null    object
#  11  num_core          941 non-null    object
#  12  processor_speed   862 non-null    float64
#  13  ram               997 non-null    float64
#  14  memory            997 non-null    object
#  15  battery           997 non-null    str
#  16  battery_capacity  997 non-null    object
# ...

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  ...  \
# ...

# %%
refrash_rate=df1['display'].str.strip().str.split(',').str.get(2)

# %%
df1.insert(19,'refrash_rate',refrash_rate)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  ...  \
# ...

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                74
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera               40
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera               38
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera               34
# 50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front Camera     34
#                                                           ..
# 48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera      1
# 64 MP Quad Rear & 16 MP Front Camera                       1
# 12 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera     1
# 48 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera      1
# 50 MP + 48 MP + 10 MP Triple Rear & 12 MP Front Camera     1
# Name: count, Length: 208, dtype: int64

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  ...  \
# ...

# %%
rear_part = df1['camera'].str.split(' ').str.get(0)

# 'errors=coerce' দিলে 'Foldable' এর মতো শব্দগুলো NaN হয়ে যাবে, এরর দিবে না
rear_camera = pd.to_numeric(rear_part, errors='coerce')

# ২. Front Camera আলাদা করা
front_part = df1['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0)
front_camera = pd.to_numeric(front_part, errors='coerce')

# %%
df1.drop(columns=['rear_camera','front_camera'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 df1.drop(columns=['rear_camera','front_camera'], inplace=True)
#
# File d:\code\.venv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
# ...

# %%
df1.insert(21,'rear_camera',rear_camera)
df1.insert(22,'front_camera',front_camera)

# %%
# ব্যাটারি থেকে শুধু সংখ্যাটি নেওয়া (যেমন: 9000 mAh -> 9000)
df1['battery_capacity'] = df1['battery_capacity'].str.split(' ').str.get(0).astype(float)

# ফাস্ট চার্জিং থেকে সংখ্যা নেওয়া (যেমন: 80W -> 80)
df1['fast_charging'] = df1['fast_charging'].str.extract('(\d+)').astype(float)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25956\3673254891.py:5: SyntaxWarning: invalid escape sequence '\d'
#   df1['fast_charging'] = df1['fast_charging'].str.extract('(\d+)').astype(float)

# %%
df1.rename(columns={'battery_capacity': 'battery_capacity(mAh)', 'fast_charging': 'fast_charging(W)'}, inplace=True)

# %%
screeen_size=df1['display'].str.strip().str.split(',').str.get(0)

# %%
df1.insert(18,'screeen_size',screeen_size)

# %%
df1.drop(columns=['display'],inplace=True)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec scroe  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  ...  \
# ...

# %%
# '120 Hz Display' থেকে শুধু '120' আলাদা করা
df1['refrash_rate'] = df1['refrash_rate'].str.extract('(\d+)').astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25956\713439712.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df1['refrash_rate'] = df1['refrash_rate'].str.extract('(\d+)').astype(float)

# %%
df1.rename(columns={'refrash_rate': 'refresh_rate', 'spec scroe': 'spec_score'}, inplace=True)

# %%
# memory থেকে শুধু সংখ্যা বের করা
df1['memory'] = df1['memory'].str.extract('(\d+)').astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25956\2566268053.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df1['memory'] = df1['memory'].str.extract('(\d+)').astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   brand_name             997 non-null    object
#  1   model                  997 non-null    str
#  2   price                  997 non-null    int64
#  3   spec_score             997 non-null    int64
#  4   sim                    997 non-null    str
#  5   has_5G                 997 non-null    bool
#  6   has_NFC                997 non-null    bool
#  7   has_IR                 997 non-null    bool
#  8   processor              997 non-null    str
#  9   processor_brand        996 non-null    object
#  10  processor_name         997 non-null    object
#  11  num_core               941 non-null    object
#  12  processor_speed        862 non-null    float64
#  13  ram                    997 non-null    float64
#  14  memory                 997 non-null    float64
# ...

# %%
df1.shape
# Out:
# (997, 24)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec_score  \
# 0    oneplus            OnePlus Nord 6   38999          81
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89
# 2       vivo               Vivo T5 Pro   29999          72
# 3    samsung     Samsung Galaxy S25 FE   50743          77
# 4       vivo               Vivo T5x 5G   18999          66
#
#                                                  sim  has_5G  has_NFC  has_IR  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True    True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...    True    False    True
# 3      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True   False
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False    True
#
#                                            processor processor_brand  ...  \
# ...

# %%
# (\d+\.?\d*) এটি দশমিকসহ সংখ্যা খুঁজে বের করবে (যেমন: 6.78)
df1['screeen_size'] = df1['screeen_size'].str.extract('(\d+\.?\d*)').astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25956\446452535.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df1['screeen_size'] = df1['screeen_size'].str.extract('(\d+\.?\d*)').astype(float)

# %%
df1.drop(columns=['sim'],inplace=True)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec_score  has_5G  has_NFC  \
# 0    oneplus            OnePlus Nord 6   38999          81    True     True
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89    True     True
# 2       vivo               Vivo T5 Pro   29999          72    True    False
# 3    samsung     Samsung Galaxy S25 FE   50743          77    True     True
# 4       vivo               Vivo T5x 5G   18999          66    True    False
#
#    has_IR                                          processor processor_brand  \
# 0    True   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor      snapdragon
# 1   False  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...      snapdragon
# 2    True            Snapdragon 7s Gen4, Octa Core Processor      snapdragon
# 3   False          Exynos 2400, Deca Core, 3.2 GHz Processor          exynos
# 4    True  Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...       dimensity
#
# ...

# %%
df1.shape
# Out:
# (997, 23)

# %%
df1['price']=df1['price'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   brand_name             997 non-null    object
#  1   model                  997 non-null    str
#  2   price                  997 non-null    int64
#  3   spec_score             997 non-null    int64
#  4   has_5G                 997 non-null    bool
#  5   has_NFC                997 non-null    bool
#  6   has_IR                 997 non-null    bool
#  7   processor              997 non-null    str
#  8   processor_brand        996 non-null    object
#  9   processor_name         997 non-null    object
#  10  num_core               941 non-null    object
#  11  processor_speed        862 non-null    float64
#  12  ram                    997 non-null    float64
#  13  memory                 997 non-null    float64
#  14  battery                997 non-null    str
# ...

# %%
df1.drop(columns=['processor'],inplace=True)

# %%
df1.rename(columns={'screeen_size': 'screen_size'}, inplace=True)

# %%
df1.head()
# Out:
#   brand_name                     model   price  spec_score  has_5G  has_NFC  \
# 0    oneplus            OnePlus Nord 6   38999          81    True     True
# 1    samsung  Samsung Galaxy S25 Ultra  110000          89    True     True
# 2       vivo               Vivo T5 Pro   29999          72    True    False
# 3    samsung     Samsung Galaxy S25 FE   50743          77    True     True
# 4       vivo               Vivo T5x 5G   18999          66    True    False
#
#    has_IR processor_brand                 processor_name   num_core  ...  \
# 0    True      snapdragon             Snapdragon 8s Gen4  Octa Core  ...
# 1   False      snapdragon  Snapdragon 8 Elite for Galaxy  Octa Core  ...
# 2    True      snapdragon             Snapdragon 7s Gen4  Octa Core  ...
# 3   False          exynos                    Exynos 2400  Deca Core  ...
# 4    True       dimensity           Dimensity 7400 Turbo  Octa Core  ...
#
# ...

# %%
# Samsung ফোনের ক্ষেত্রে যদি 'octa' থাকে তবে সেগুলোকে 'exynos' বা 'samsung' হিসেবে মার্ক করা
df1.loc[(df1['brand_name'] == 'samsung') & (df1['processor_brand'] == 'octa'), 'processor_brand'] = 'exynos'

# Huawei-এর ক্ষেত্রে 'kirin' হতে পারে
df1.loc[(df1['brand_name'] == 'huawei') & (df1['processor_brand'] == 'octa'), 'processor_brand'] = 'kirin'

# %%
df1.loc[(df1['brand_name'] == 'oneplus') & (df1['processor_brand'] == 'octa'), 'processor_brand'] = 'snapdragon'

# %%
# Replace 'octa' with 'unknown' or 'other' to keep the brand column clean
df1['processor_brand'] = df1['processor_brand'].replace('octa', 'unknown')

# %%
# Example: If you know specific models use a certain brand
df1.loc[df1['model'].str.contains('Vivo T5 Ultra', case=False), 'processor_brand'] = 'dimensity'

# %%
df1.loc[df1['processor_brand'] == 'unknown', 'num_core'] = 'Octa Core'

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997 entries, 0 to 1019
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   brand_name             997 non-null    object
#  1   model                  997 non-null    str
#  2   price                  997 non-null    int64
#  3   spec_score             997 non-null    int64
#  4   has_5G                 997 non-null    bool
#  5   has_NFC                997 non-null    bool
#  6   has_IR                 997 non-null    bool
#  7   processor_brand        996 non-null    object
#  8   processor_name         997 non-null    object
#  9   num_core               980 non-null    object
#  10  processor_speed        862 non-null    float64
#  11  ram                    997 non-null    float64
#  12  memory                 997 non-null    float64
#  13  battery                997 non-null    str
#  14  battery_capacity(mAh)  997 non-null    float64
# ...

# %%
df1.to_csv('mobile2',index=False)
